# %% [markdown]
# <a href="https://colab.research.google.com/github/bessonvv/III_Semestr_Mifi_Ml/blob/main/goodbooks_10k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Подключение библиотек

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install kaggle

# %%
import getpass
import os

os.environ["KAGGLE_USERNAME"] = input("Kaggle username: ")
os.environ["KAGGLE_KEY"] = getpass.getpass("Kaggle API key: ")
# Out:
# Kaggle username: bessonvv
# Kaggle API key: ··········

# %%
# !kaggle datasets download zygmunt/goodbooks-10k -p ./bessonv/data --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/zygmunt/goodbooks-10k
# License(s): CC-BY-SA-4.0
# ...
#   0% 0.00/11.6M [00:00<?, ?B/s]
# 100% 11.6M/11.6M [00:00<00:00, 683MB/s]

# %% [markdown]
# # Этап 1: знакомство с данными и EDA (Exploratory Data Analysis)
